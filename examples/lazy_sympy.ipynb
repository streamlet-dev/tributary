# %%
import tributary.symbolic as ts

# %%
expr = ts.parse_expression("10sin**2 x**2 + 3xyz + tan theta")
# ts.graphviz(expr)

# %%
clz = ts.construct_lazy(expr)
x = clz(x=1, y=2, z=3, theta=4)
# Out:
# ['y', 'x', 'theta', 'z']

# %%
x
# Out:
# <tributary.symbolic.construct_lazy.<locals>.Lazy at 0x114189dd8>

# %%
x.evaluate()()
# Out:
# 26.238555465085287

# %%
x.x = 2
x.evaluate()()
# Out:
# 42.88532145139265

# %%
x.evaluate().graphviz()

# %%
expr
# Out:
#                 2⎛ 2⎞
# 3⋅x⋅y⋅z + 10⋅sin ⎝x ⎠ + tan(θ)
